# %%
import numpy as np
import pandas as pd
from typing import Generator, Tuple
from sklearn.linear_model import LinearRegression
from scripts import validation as tsvm

# %%
validator = tsvm.ValidationTimeSeriesSplit(
    min_train_size=3,
    val_size=1,
    gap=0,
    test_size=1
)

# %%
model = tsvm.XGBModel(validator=validator, params={
            'n_estimators': 1000,
            'learning_rate': 0.1,
            'max_depth': 8,
            'subsample': 0.8,
            'colsample_bytree': 0.8,
            'early_stopping_rounds': 100,
            'eval_metric': 'rmse',
            'enable_categorical': True
})

# %%
da = pd.read_csv('sales_train_complete.csv')
kaggle_test = pd.read_csv('../competitive-data-science-predict-future-sales/test.csv')

# %%
df_monthly = da.groupby(['date__month', 'shop_id', 'item_id']).agg({
    'item_cnt_day': 'sum',          
    'item_price': 'last',           
    'item_category_id': 'first',    
    'shop_name': 'first',           
    'date__day_of_month': 'count',  
    'date__month_of_year': 'first',  
    'date__year': 'first'           
}).reset_index()

df_monthly = df_monthly.rename(columns={
    'item_cnt_day': 'item_cnt_month',
    'date__day_of_month': 'sales_days_in_month'
})

if 'date' in df_monthly.columns:
    df_monthly = df_monthly.drop(columns=['date'])

df_monthly = df_monthly[[
    'date__month',
    'shop_id',
    'item_id',
    'item_price',
    'item_cnt_month',
    'item_category_id',
    'shop_name',
    'sales_days_in_month',
    'date__month_of_year',
    'date__year'
]]

# %%
df_monthly
# Out:
#         date__month  shop_id  item_id  item_price  item_cnt_month  \
# 0                 0        2       33       499.0             1.0
# 1                 0        2      482      3300.0             1.0
# 2                 0        2      491       600.0             1.0
# 3                 0        2      839      3300.0             1.0
# 4                 0        2     1007       449.0             3.0
# ...             ...      ...      ...         ...             ...
# 540592           33       59    22087       119.0             6.0
# 540593           33       59    22088       119.0             2.0
# 540594           33       59    22091       179.0             1.0
# 540595           33       59    22100       629.0             1.0
# 540596           33       59    22102      1250.0             1.0
#
#         item_category_id               shop_name  sales_days_in_month  \
# 0                     37        Адыгея ТЦ "Мега"                    1
# 1                     73        Адыгея ТЦ "Мега"                    1
# 2                     73        Адыгея ТЦ "Мега"                    1
# 3                     73        Адыгея ТЦ "Мега"                    1
# 4                     67        Адыгея ТЦ "Мега"                    3
# ...                  ...                     ...                  ...
# 540592                83  Ярославль ТЦ "Альтаир"                    3
# 540593                83  Ярославль ТЦ "Альтаир"                    2
# 540594                83  Ярославль ТЦ "Альтаир"                    1
# 540595                42  Ярославль ТЦ "Альтаир"                    1
# 540596                42  Ярославль ТЦ "Альтаир"                    1
#
#         date__month_of_year  date__year
# 0                         1        2013
# 1                         1        2013
# 2                         1        2013
# 3                         1        2013
# 4                         1        2013
# ...                     ...         ...
# 540592                   10        2015
# 540593                   10        2015
# 540594                   10        2015
# 540595                   10        2015
# 540596                   10        2015
#
# [540597 rows x 10 columns]

# %%
def prepare_test_data(train_df: pd.DataFrame, test_df: pd.DataFrame) -> pd.DataFrame:
    """
    Enhance test data with features from last available training month
    """
    last_month = train_df['date__month'].max()
    last_month_data = train_df[train_df['date__month'] == last_month]
    
    item_features = train_df[['item_id', 'item_category_id']].drop_duplicates()
    
    test_enhanced = test_df.merge(
        last_month_data[['shop_id', 'item_id', 'item_price']],
        on=['shop_id', 'item_id'],
        how='left'
    )
    
    last_prices = train_df.groupby('item_id')['item_price'].last().reset_index()
    test_enhanced = test_enhanced.merge(
        last_prices,
        on='item_id',
        how='left',
        suffixes=('', '_last')
    )
    test_enhanced['item_price'] = test_enhanced['item_price'].fillna(test_enhanced['item_price_last'])
    
    test_enhanced = test_enhanced.merge(
        item_features,
        on='item_id',
        how='left'
    )
    
    test_enhanced['date__month'] = last_month + 1
    test_enhanced['date__year'] = last_month_data['date__year'].iloc[0]
    test_enhanced['date__month_of_year'] = (last_month % 12) + 2
    
    return test_enhanced[[
        'ID',
        'date__month',
        'shop_id',
        'item_id',
        'item_price',
        'item_category_id',
        'date__month_of_year',
        'date__year'
    ]]

# %%
prepared_test_df = prepare_test_data(df_monthly, kaggle_test)
df_monthly.drop(columns=['sales_days_in_month', 'shop_name'], inplace=True)
prepared_df = prepared_test_df.drop(columns='ID')
prepared_df
# Out:
#         date__month  shop_id  item_id  item_price  item_category_id  \
# 0                34        5     5037      1499.0              19.0
# 1                34        5     5320         NaN               NaN
# 2                34        5     5233      1199.0              19.0
# 3                34        5     5232      1199.0              23.0
# 4                34        5     5268         NaN               NaN
# ...             ...      ...      ...         ...               ...
# 214195           34       45    18454        99.0              55.0
# 214196           34       45    16188      1359.0              64.0
# 214197           34       45    15757       229.0              55.0
# 214198           34       45    19648        79.2              40.0
# 214199           34       45      969       198.0              37.0
#
#         date__month_of_year  date__year
# 0                        11        2015
# 1                        11        2015
# 2                        11        2015
# 3                        11        2015
# 4                        11        2015
# ...                     ...         ...
# 214195                   11        2015
# 214196                   11        2015
# 214197                   11        2015
# 214198                   11        2015
# 214199                   11        2015
#
# [214200 rows x 7 columns]

# %%
df_monthly
# Out:
#         date__month  shop_id  item_id  item_price  item_cnt_month  \
# 0                 0        2       33       499.0             1.0
# 1                 0        2      482      3300.0             1.0
# 2                 0        2      491       600.0             1.0
# 3                 0        2      839      3300.0             1.0
# 4                 0        2     1007       449.0             3.0
# ...             ...      ...      ...         ...             ...
# 540592           33       59    22087       119.0             6.0
# 540593           33       59    22088       119.0             2.0
# 540594           33       59    22091       179.0             1.0
# 540595           33       59    22100       629.0             1.0
# 540596           33       59    22102      1250.0             1.0
#
#         item_category_id  date__month_of_year  date__year
# 0                     37                    1        2013
# 1                     73                    1        2013
# 2                     73                    1        2013
# 3                     73                    1        2013
# 4                     67                    1        2013
# ...                  ...                  ...         ...
# 540592                83                   10        2015
# 540593                83                   10        2015
# 540594                83                   10        2015
# 540595                42                   10        2015
# 540596                42                   10        2015
#
# [540597 rows x 8 columns]

# %%
# Some tests for splits

splits, test_idx = validator.split(df_monthly)

is_valid_splits = validator.validate_splits(df_monthly, splits)

has_minimum_data = validator.check_minimum_data(df_monthly)

features = ['shop_id', 'item_id', 'item_price']
target = 'item_cnt_month'
has_leakage = validator.check_target_leakage(features, target, df_monthly)

is_validation_sufficient, ks = validator.check_validation_sufficiency(df_monthly)


is_data_adequate = validator.check_data_adequacy(df_monthly)
print(f"\tVALIDATION:\nAre splits valid? {is_valid_splits}\nHas enough data for validation? {has_minimum_data}\nIs there target leakage? {has_leakage}\nIs validation representative? {is_validation_sufficient}\nIs there enough data for stable validation? {is_data_adequate}")
# Out:
# 	VALIDATION:
# Are splits valid? True
# Has enough data for validation? True
# Is there target leakage? True
# Is validation representative? True
# Is there enough data for stable validation? True

# %%
model.fit(df_monthly)
# Out:
# Window 1 - Train: 0 to 24310 | Val: 24311 to 32105 | Best Iteration: 9 | RMSE: 2.7905
# Window 2 - Train: 0 to 32105 | Val: 32106 to 40000 | Best Iteration: 31 | RMSE: 2.6094
# Window 3 - Train: 0 to 40000 | Val: 40001 to 48481 | Best Iteration: 37 | RMSE: 2.3529
# Window 4 - Train: 0 to 48481 | Val: 48482 to 57568 | Best Iteration: 311 | RMSE: 2.1172
# Window 5 - Train: 0 to 57568 | Val: 57569 to 67303 | Best Iteration: 273 | RMSE: 2.4693
# Window 6 - Train: 0 to 67303 | Val: 67304 to 76596 | Best Iteration: 112 | RMSE: 2.9411
# Window 7 - Train: 0 to 76596 | Val: 76597 to 86665 | Best Iteration: 223 | RMSE: 3.9224
# Window 8 - Train: 0 to 86665 | Val: 86666 to 97686 | Best Iteration: 8 | RMSE: 3.4474
# Window 9 - Train: 0 to 97686 | Val: 97687 to 112524 | Best Iteration: 364 | RMSE: 3.8842
# Window 10 - Train: 0 to 112524 | Val: 112525 to 125241 | Best Iteration: 41 | RMSE: 2.7312
# Window 11 - Train: 0 to 125241 | Val: 125242 to 137640 | Best Iteration: 499 | RMSE: 2.4031
# Window 12 - Train: 0 to 137640 | Val: 137641 to 151450 | Best Iteration: 64 | RMSE: 3.0504
# Window 13 - Train: 0 to 151450 | Val: 151451 to 164503 | Best Iteration: 97 | RMSE: 2.4129
# Window 14 - Train: 0 to 164503 | Val: 164504 to 178620 | Best Iteration: 104 | RMSE: 1.9835
# Window 15 - Train: 0 to 178620 | Val: 178621 to 193910 | Best Iteration: 727 | RMSE: 2.3447
# Window 16 - Train: 0 to 193910 | Val: 193911 to 209801 | Best Iteration: 71 | RMSE: 2.1971
# Window 17 - Train: 0 to 209801 | Val: 209802 to 227699 | Best Iteration: 323 | RMSE: 2.7581
# Window 18 - Train: 0 to 227699 | Val: 227700 to 243895 | Best Iteration: 43 | RMSE: 2.3173
# Window 19 - Train: 0 to 243895 | Val: 243896 to 261702 | Best Iteration: 381 | RMSE: 2.8337
# Window 20 - Train: 0 to 261702 | Val: 261703 to 282007 | Best Iteration: 176 | RMSE: 2.8132
# Window 21 - Train: 0 to 282007 | Val: 282008 to 310182 | Best Iteration: 422 | RMSE: 3.2424
# Window 22 - Train: 0 to 310182 | Val: 310183 to 333577 | Best Iteration: 123 | RMSE: 2.4243
# Window 23 - Train: 0 to 333577 | Val: 333578 to 355707 | Best Iteration: 241 | RMSE: 1.9448
# Window 24 - Train: 0 to 355707 | Val: 355708 to 378294 | Best Iteration: 495 | RMSE: 1.9701
# Window 25 - Train: 0 to 378294 | Val: 378295 to 398422 | Best Iteration: 208 | RMSE: 2.4171
# Window 26 - Train: 0 to 398422 | Val: 398423 to 419363 | Best Iteration: 117 | RMSE: 2.0213
# Window 27 - Train: 0 to 419363 | Val: 419364 to 441218 | Best Iteration: 484 | RMSE: 1.9175
# Window 28 - Train: 0 to 441218 | Val: 441219 to 465136 | Best Iteration: 512 | RMSE: 1.6399
# Window 29 - Train: 0 to 465136 | Val: 465137 to 491220 | Best Iteration: 560 | RMSE: 1.7156
# Window 30 - Train: 0 to 491220 | Val: 491221 to 514999 | Best Iteration: 374 | RMSE: 1.9796

# %%
predictions = model.predict(prepared_df)

# %%
kaggle_test['item_cnt_month'] = predictions
kaggle_test.drop(columns=['shop_id','item_id'], inplace=True)

# %%
kaggle_test.to_csv('test_submission.csv', index=False)
